# %%
import pandas as pd

arquivo_csv = "../data/raw/dados_cvm_filtrando_status.csv"

df = pd.read_csv(arquivo_csv)
print(df.head())
# Out:
#    idRequerimento  totalRegistros numeroProtocolo numeroProcesso  \
# 0           22032            4247       2652/2025  SRE/2650/2025
# 1           21838            4247       2554/2025  SRE/2553/2025
# 2           21842            4247       2553/2025  SRE/2552/2025
# 3           21841            4247       2552/2025  SRE/2551/2025
# 4           21863            4247       2534/2025  SRE/2533/2025
#
#                                       numeroRegistro nomeValorMobiliario  \
# 0                       CVM/SRE/AUT/DEB/PRI/2025/663          Debêntures
# 1  CVM/SRE/AUT/DEB/PRI/2025/661;CVM/SRE/AUT/DEB/P...          Debêntures
# 2  CVM/SRE/AUT/DEB/PRI/2025/659;CVM/SRE/AUT/DEB/P...          Debêntures
# 3  CVM/SRE/AUT/DEB/PRI/2025/657;CVM/SRE/AUT/DEB/P...          Debêntures
# 4                       CVM/SRE/AUT/DEB/PRI/2025/656          Debêntures
#
#   tipoDeOferta      statusDaOferta  \
# 0     PRIMARIA  Registro Concedido
# 1     PRIMARIA  Registro Concedido
# 2     PRIMARIA  Registro Concedido
# 3     PRIMARIA  Registro Concedido
# 4     PRIMARIA    Oferta Encerrada
#
#                                          nomeEmissor         cnpjEmissor  \
# 0                                        ENERGISA SA  00.864.214/0001-06
# 1  ENERGISA MATO GROSSO DO SUL - DIST DE ENERGIA ...  15.413.826/0001-50
# 2    ENERGISA SERGIPE - DISTRIBUIDORA DE ENERGIA S/A  13.017.462/0001-63
# 3  ENERGISA MATO GROSSO-DISTRIBUIDORA DE ENERGIA S/A  03.467.321/0001-99
# 4                                   CBO HOLDING S.A.  14.882.295/0001-81
#
#                    nomeCoordenadorLider cnpjCoordenadorLider  \
# 0  BTG PACTUAL INVESTMENT BANKING LTDA.   46.482.072/0001-13
# 1    ITAU BBA ASSESSORIA FINANCEIRA S.A   04.845.753/0001-59
# 2    ITAU BBA ASSESSORIA FINANCEIRA S.A   04.845.753/0001-59
# 3    ITAU BBA ASSESSORIA FINANCEIRA S.A   04.845.753/0001-59
# 4         BANCO SANTANDER (BRASIL) S.A.   90.400.888/0001-42
#
#     valorTotalEmReais        data  \
# 0  3.649.661.000,0000  17/09/2025
# 1    900.000.000,0000  16/09/2025
# 2    590.000.000,0000  16/09/2025
# 3  1.000.000.000,0000  16/09/2025
# 4    522.500.000,0000  15/09/2025
#
#                                 nomeTipoRequerimento  vasoComunicante  \
# 0  OPD Aut Profissional - com bookbuilding - EGEM...            False
# 1  OPD Aut Público em Geral ou Qualificado - com ...             True
# 2  OPD Aut Público em Geral ou Qualificado - com ...             True
# 3  OPD Aut Público em Geral ou Qualificado - com ...             True
# 4            OPD Aut Profissional - com bookbuilding            False
#
#    possuiBook  registroAutomatico
# 0        True                True
# 1        True                True
# 2        True                True
# 3        True                True
# 4        True                True

# %%
df['idRequerimento'].head(10).tolist()
# Out:
# [22032, 21838, 21842, 21841, 21863, 21069, 21567, 21972, 21984, 21899]

# %%
# colunas_finais = [
#     "COD. NEGOCIACAO",
#     "EMISSOR",
#     "AG. FIDUCIARIO",
#     "EMISSÃO",
#     "SÉRIE",
#     "QTDE EMITIDA",
#     "VOL. EMISSÃO",
#     "QTDE INTEC",
#     "INDICADOR",
#     "TAXA",
#     "SITUAÇÃO",
#     "DATA EMISSÃO",
#     "DATA VENC",
#     "ISIN",
#     "OFERTA CVM"
# ]

# # Criar dataframe vazio com essas colunas
# preencher = pd.DataFrame(columns=colunas_finais)
# preencher['OFERTA CVM'] = df['numeroRegistro']

# %%
# Out:
#    COD. NEGOCIACAO EMISSOR AG. FIDUCIARIO EMISSÃO SÉRIE QTDE EMITIDA  \
# 3              NaN     NaN            NaN     NaN   NaN          NaN
# 4              NaN     NaN            NaN     NaN   NaN          NaN
# 15             NaN     NaN            NaN     NaN   NaN          NaN
# 23             NaN     NaN            NaN     NaN   NaN          NaN
# 32             NaN     NaN            NaN     NaN   NaN          NaN
#
#    VOL. EMISSÃO QTDE INTEC INDICADOR TAXA SITUAÇÃO DATA EMISSÃO DATA VENC  \
# 3           NaN        NaN       NaN  NaN      NaN          NaN       NaN
# 4           NaN        NaN       NaN  NaN      NaN          NaN       NaN
# 15          NaN        NaN       NaN  NaN      NaN          NaN       NaN
# 23          NaN        NaN       NaN  NaN      NaN          NaN       NaN
# 32          NaN        NaN       NaN  NaN      NaN          NaN       NaN
#
#    ISIN                                         OFERTA CVM
# 3   NaN                       CVM/SRE/AUT/DEB/PRI/2025/626
# 4   NaN                       CVM/SRE/AUT/DEB/PRI/2025/625
# 15  NaN                                                NaN
# 23  NaN  CVM/SRE/AUT/DEB/PRI/2025/623;CVM/SRE/AUT/DEB/P...
# 32  NaN                       CVM/SRE/AUT/DEB/PRI/2025/622
